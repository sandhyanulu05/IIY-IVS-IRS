# %% [markdown]
# <a href="https://colab.research.google.com/github/sandhyanulu05/IIY-IVS-IRS/blob/main/classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

#dataset
text_data=[
    "free ticket win",
    "good morning",
    "earn money online",
    "how are you",
    "claim your prize",
    "nice to meet you"
]

labels = [1,0,1,0,1,0]
data = pd.DataFrame({'text': text_data, 'label': labels})
print("Dataset used : ")
print(data)

#convert data into numbers
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(data["text"])

y = data["label"]

#Train model
lr = LogisticRegression()
lr.fit(X,y)

#prediction
test = ["win free ticket"]
test_vec = vectorizer.transform(test)

prediction = lr.predict(test_vec)

print("\nTesting Message: ",test[0])
if(prediction[0]==1):
    print("Spam")
else:
    print("Not Spam")
